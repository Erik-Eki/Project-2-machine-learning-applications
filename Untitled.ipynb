# %% [markdown]
# # Klusterointi reiteille

# %%
import sys
import pandas as pd
sys.path.insert(0, './Moduulit')
pd.options.mode.chained_assignment = None

from ipywidgets import interact, interactive, fixed, interact_manual, Layout
import ipywidgets as widgets


# Importtaus tässä muodossa
from database_connection import database_query
from outliers import find_outliers, draw_histogram
from clean_dataframe import clean_dataframe
from draw_node_amount import *
from write_df_to_database import write_df_to_mariadb
from xy_diskretisointi import xy_to_grid
from reittien_erottelu import *
from isolation_forest import *
from sisään_uloskäynnit import *
from horrostila import *
from widgets import *
from plot_lapimenoajat import *
from histogrammi_3D import *
# tai from ... import *

# %%
df = database_query("SELECT * FROM SensorData limit 1000000")
df.head()
# Out:
#                    node_id                            timestamp     x    y  \
# 0  b'-2393099149039893833'  b'2020-06-24 12:20:08.533016+00:00'  2762 -257
# 1  b'-2393099149039893833'  b'2020-06-24 12:20:08.620015+00:00'  2870 -344
# 2  b'-2393099149039893833'  b'2020-06-24 12:20:09.622827+00:00'  2916 -344
# 3  b'-2393099149039893833'  b'2020-06-24 12:20:09.622846+00:00'  2894 -254
# 4  b'-2393099149039893833'  b'2020-06-24 12:20:10.116102+00:00'  2888 -188
#
#      z  q
# 0  100  0
# 1  100  0
# 2  100  0
# 3  100  0
# 4  100  0

# %%
df1 = find_outliers(df)
# Out:
# Number of missing variables in table
#  node_id      0
# timestamp    0
# x            0
# y            0
# z            0
# q            0
# dtype: int64
# ------------------------------
# Unique values in columns
#
# uniques in x 5161
# uniques in y 5033
# uniques in z 1
# uniques in q 1
# ------------------------------
# Checking z and q columns
#
# uniques in z [100]
# uniques in q [0]
# ------------------------------
# Number of nodes: 3
# ------------------------------
# Outliers
#
# Data with outliers:  1000000
# Ouliers removed:     6483
# Data after:  993517

# %%
df2 = clean_dataframe(df1)
df2.head()
# Out:
#    node_id               timestamp     x    y  dayofweek  current_hour
# 0        1 2020-06-24 15:20:08.533  2762 -257          2             8
# 1        1 2020-06-24 15:20:08.620  2870 -344          2             8
# 2        1 2020-06-24 15:20:09.623  2916 -344          2             8
# 3        1 2020-06-24 15:20:09.623  2894 -254          2             8
# 4        1 2020-06-24 15:20:10.116  2888 -188          2             8

# %%
df2
# Out:
#         node_id               timestamp     x    y  dayofweek  current_hour
# 0             1 2020-06-24 15:20:08.533  2762 -257          2             8
# 1             1 2020-06-24 15:20:08.620  2870 -344          2             8
# 2             1 2020-06-24 15:20:09.623  2916 -344          2             8
# 3             1 2020-06-24 15:20:09.623  2894 -254          2             8
# 4             1 2020-06-24 15:20:10.116  2888 -188          2             8
# ...         ...                     ...   ...  ...        ...           ...
# 932744        3 2020-08-16 12:08:11.426  1938 -267          6             3
# 932745        3 2020-08-16 12:08:20.426  1922 -242          6             3
# 932746        3 2020-08-16 12:08:39.426  2002 -332          6             3
# 932747        3 2020-08-16 12:09:16.426  1961 -281          6             3
# 932748        3 2020-08-16 12:09:35.426  1934 -246          6             3
#
# [932749 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.ensemble import IsolationForest


def isolation_forest2(df, random_state, contamination):
    
    #df_final = pd.DataFrame()
    #for i in range(len(df.node_id.unique())):

    
    # x ja y arvot talteen
    x_temp = df.loc[df['node_id']==1][['x', 'y']]
    
    print('1/20')
    
    # Init minmaxscaler + fit+transform
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x_temp)
    
    print('2/20')
    # Normalisoidut arvot uuteen dataframeen
    xy_normalized = pd.DataFrame(x_scaled)
    xy_normalized = xy_normalized.rename(columns={0: 'x', 1: 'y'})
    
    print('3/20')
    # Isolationforest annetuin parametrein + fit
    clf = IsolationForest(max_samples=len(x_scaled),random_state=random_state, contamination=contamination) 
    clf.fit(xy_normalized)
    
    filename = 'mymodel.sav'
    pickle.dump(clf, open(filename, 'wb'))

    print('4/20 - fit DONE')
    
    # Outlier detect
    if_scores = clf.decision_function(xy_normalized)
    print('brah 1')
    if_anomalies=clf.predict(xy_normalized)
    print('brah 2')
    if_anomalies=pd.Series(if_anomalies).replace([-1,1],[1,0])
    print('brah 3')
    if_anomalies=xy_normalized[if_anomalies==1]
    
    print('5/20')
    
    outliers = x_temp.loc[if_anomalies.index.values]
    print('Dataframe lenght before:', len(x_temp))

    # Drop outliers from df + reset index
    x_temp = x_temp.drop(x_temp.index[if_anomalies.index.values])

    # Grab that sweet timestamp
    df = df.loc[x_temp.index]
    df = df.reset_index(drop=True)

    print('Dataframe lenght after:', len(df))
    print('Total outliers detected:', len(if_anomalies))

    #Plot results
    #plt.gca().invert_yaxis()
    plt.scatter(df['x'],df['y'],edgecolor='black',s=15)
    plt.scatter(outliers['x'],outliers['y'],edgecolor='red',s=15)
    plt.show()

    #df_final = df_final.append(df)
    return df

# %%
# %%time
df3 = isolation_forest2(df2, 0, .001)
# Out:
# 1/20
# 2/20
# 3/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-55-0fc1d11e754a> in isolation_forest2(df, random_state, contamination)
#      29     # Isolationforest annetuin parametrein + fit
#      30     clf = IsolationForest(max_samples=len(x_scaled),random_state=random_state, contamination=contamination)
# ---> 31     clf.fit(xy_normalized)
#      32
#      33     filename = 'mymodel.sav'
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_iforest.py in fit(self, X, y, sample_weight)
#     300         super()._fit(X, y, max_samples,
#     301                      max_depth=max_depth,
# --> 302                      sample_weight=sample_weight)
#     303
#     304         if self.contamination == "auto":
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     378                 total_n_estimators,
#     379                 verbose=self.verbose)
# --> 380             for i in range(n_jobs))
#     381
#     382         # Reduce
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /opt/conda/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /opt/conda/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/conda/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/_bagging.py in _parallel_build_estimators(n_estimators, ensemble, X, y, sample_weight, seeds, total_n_estimators, verbose)
#     108                 curr_sample_weight[not_indices_mask] = 0
#     109
# --> 110             estimator.fit(X[:, features], y, sample_weight=curr_sample_weight)
#     111
#     112         else:
#
# /opt/conda/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1244             sample_weight=sample_weight,
#    1245             check_input=check_input,
# -> 1246             X_idx_sorted=X_idx_sorted)
#    1247         return self
#    1248
#
# /opt/conda/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
df3.loc[df3.node_id==1]
# Out:
#         node_id               timestamp     x    y  dayofweek  current_hour
# 0             1 2020-06-24 15:20:08.533  2762 -257          2             8
# 1             1 2020-06-24 15:20:08.620  2870 -344          2             8
# 2             1 2020-06-24 15:20:09.623  2916 -344          2             8
# 3             1 2020-06-24 15:20:09.623  2894 -254          2             8
# 4             1 2020-06-24 15:20:10.116  2888 -188          2             8
# ...         ...                     ...   ...  ...        ...           ...
# 541627        1 2020-10-23 09:57:02.989  2766 -339          4             2
# 541628        1 2020-10-23 09:57:21.989  2772 -354          4             2
# 541629        1 2020-10-23 09:57:31.989  2776 -370          4             2
# 541630        1 2020-10-23 09:57:41.989  2775 -363          4             2
# 541631        1 2020-10-23 09:57:50.989  2773 -369          4             2
#
# [541632 rows x 6 columns]

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.ensemble import IsolationForest

filename = 'mymodel.sav'

def isolation_forest3(df, random_state, contamination):
    
    #df_final = pd.DataFrame()
    #for i in range(len(df.node_id.unique())):

    
    # x ja y arvot talteen
    x_temp = df.loc[df['node_id']==1][['x', 'y']]
    
    
    # Init minmaxscaler + fit+transform
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x_temp)
    
    print('2/20')
    # Normalisoidut arvot uuteen dataframeen
    xy_normalized = pd.DataFrame(x_scaled)
    xy_normalized = xy_normalized.rename(columns={0: 'x', 1: 'y'})
    
    
    #clf = pickle.load(open(filename, 'rb'))
    
    clf = IsolationForest(max_samples=len(x_scaled),random_state=random_state, contamination=contamination) 
    clf.fit(xy_normalized)
    print('4/20 - fit DONE')
    
    # Outlier detect
    #if_scores = clf.decision_function(xy_normalized)
    print('brah 1')
    if_anomalies=clf.predict(xy_normalized)
    print('brah 2')
    if_anomalies=pd.Series(if_anomalies).replace([-1,1],[1,0])
    print('brah 3')
    if_anomalies=xy_normalized[if_anomalies==1]
    
    print('5/20')
    
    outliers = x_temp.loc[if_anomalies.index.values]
    print('Dataframe lenght before:', len(x_temp))

    # Drop outliers from df + reset index
    x_temp = x_temp.drop(x_temp.index[if_anomalies.index.values])

    # Grab that sweet timestamp
    df = df.loc[x_temp.index]
    df = df.reset_index(drop=True)

    print('Dataframe lenght after:', len(df))
    print('Total outliers detected:', len(if_anomalies))

    #Plot results
    #plt.gca().invert_yaxis()
    plt.scatter(df['x'],df['y'],edgecolor='black',s=15)
    plt.scatter(outliers['x'],outliers['y'],edgecolor='red',s=15)
    plt.show()

    #df_final = df_final.append(df)
    return df

# %%
# %%time
df3 = isolation_forest3(df2, 0, .001)
#30sec enkka
# Out:
# 2/20
# 4/20 - fit DONE
# brah 1
# brah 2
# brah 3
# 5/20
# Dataframe lenght before: 542175
# Dataframe lenght after: 541632
# Total outliers detected: 543
# CPU times: user 1min 14s, sys: 164 ms, total: 1min 14s
# Wall time: 1min 13s
