# %%
import pandas as pd
import sys  
sys.path.insert(0, './Moduulit')
pd.options.mode.chained_assignment = None
# Importtaus tässä muodossa
from database_connection import database_query
from outliers import find_outliers, draw_histogram
from clean_dataframe import clean_dataframe
from write_df_to_database import write_df_to_mariadb
from xy_diskretisointi import xy_to_grid

# tai from ... import *


# Jos datasetti on "df"

# Esim. find_outliers(df)
# Esim. draw_histogram(df['x'], df['y'], 20) <-- kolmas meinaa bins arvoa, eli histogrammin "rakeisuutta"

# %%
df = pd.read_csv('projekti2.csv').head(5000000)
df
# Out:
#          Unnamed: 0                  node_id  \
# 0                 0  b'-2393099149039893833'
# 1                 1  b'-2393099149039893833'
# 2                 2  b'-2393099149039893833'
# 3                 3  b'-2393099149039893833'
# 4                 4  b'-2393099149039893833'
# ...             ...                      ...
# 4999995     4999995  b'-2393099149039894352'
# 4999996     4999996  b'-2393099149039894352'
# 4999997     4999997  b'-2393099149039894352'
# 4999998     4999998  b'-2393099149039894352'
# 4999999     4999999  b'-2393099149039894352'
#
#                                    timestamp     x     y    z  q
# 0        b'2020-06-24 12:20:08.533016+00:00'  2762  -257  100  0
# 1        b'2020-06-24 12:20:08.620015+00:00'  2870  -344  100  0
# 2        b'2020-06-24 12:20:09.622827+00:00'  2916  -344  100  0
# 3        b'2020-06-24 12:20:09.622846+00:00'  2894  -254  100  0
# 4        b'2020-06-24 12:20:10.116102+00:00'  2888  -188  100  0
# ...                                      ...   ...   ...  ... ..
# 4999995  b'2020-09-21 14:06:33.955541+00:00'  1563  1188  100  0
# 4999996  b'2020-09-21 14:06:43.956067+00:00'  1545  1193  100  0
# 4999997   b'2020-09-21 14:06:53.95596+00:00'  1550  1195  100  0
# 4999998  b'2020-09-21 14:07:03.955993+00:00'  1550  1194  100  0
# 4999999  b'2020-09-21 14:07:13.955858+00:00'  1567  1188  100  0
#
# [5000000 rows x 7 columns]

# %%
df = find_outliers(df)
# Out:
# Number of missing variables in table
#  Unnamed: 0    0
# node_id       0
# timestamp     0
# x             0
# y             0
# z             0
# q             0
# dtype: int64
# ------------------------------
# Unique values in columns
#
# uniques in x 6764
# uniques in y 6434
# uniques in z 2
# uniques in q 1
# ------------------------------
# Checking z and q columns
#
# uniques in z [100 400]
# uniques in q [0]
# ------------------------------
# Number of nodes: 13
# ------------------------------
# Outliers
#
# Data with outliers:  5000000
# Ouliers removed:     88727
# Data after:  4911273

# %%
df = clean_dataframe(df)

# %%
df.head(5)
# Out:
#    Unnamed: 0  node_id               timestamp     x    y
# 0           0        1 2020-06-24 15:20:08.533  2762 -257
# 1           1        1 2020-06-24 15:20:08.620  2870 -344
# 2           2        1 2020-06-24 15:20:09.623  2916 -344
# 3           3        1 2020-06-24 15:20:09.623  2894 -254
# 4           4        1 2020-06-24 15:20:10.116  2888 -188

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.head(10)
# Out:
#    node_id               timestamp     x    y
# 0        1 2020-06-24 15:20:08.533  2762 -257
# 1        1 2020-06-24 15:20:08.620  2870 -344
# 2        1 2020-06-24 15:20:09.623  2916 -344
# 3        1 2020-06-24 15:20:09.623  2894 -254
# 4        1 2020-06-24 15:20:10.116  2888 -188
# 5        1 2020-06-24 15:20:11.086  2910 -200
# 6        1 2020-06-24 15:20:11.820  2924 -111
# 7        1 2020-06-24 15:20:12.995  2928    5
# 8        1 2020-06-24 15:20:13.596  2987    6
# 9        1 2020-06-24 15:20:14.482  3038   -8

# %%
#df

# %%
 #määritellään aikadata tunneittain ja tehdään sille oma sarake

df['timebyhour'] = df.timestamp.dt.hour

# %%
import matplotlib.pyplot as plt
import pandas as pd


    # Määritetään värit graafia varten
my_colors = [
    'darkorange',
    'orange',
    'sandybrown',
    'lightsalmon',
    'wheat',
    'gold',
    'yellow',
    'peru',
    'red',
    'crimson',
    'magenta',
    'blue',
    'mediumblue',
    'darkblue',]


    # Napataan välimuuttujaan
df_c = df

    # Kärryt per tunti
df_c['timebyhour'].value_counts(sort=False, normalize=True).mul(100).plot(kind='bar', color=my_colors, edgecolor='black');


# X-akselin teksti
plt.xlabel("Kellonaika", labelpad=14)


    # Pystyakselin teksti
plt.ylabel("Osuus kokonaisuudesta (%)", labelpad=14)
    
    
    # Otsikko johon päivämäärät datasta
plt.title("Kärryjä kaupassa kellonaikaan aikajaksolla:\n " + str(df.timestamp.dt.date.iloc[0]) + " - " + str(df.timestamp.dt.date.iloc[-1]), y=1.02, fontsize=10);

# %%
df = df.drop(df[(df.timestamp.dt.hour < 8)].index)
df = df.drop(df[(df.timestamp.dt.hour > 21)].index)

# %%
import matplotlib.pyplot as plt
import pandas as pd


    # Määritetään värit graafia varten
my_colors = [
    'darkorange',
    'orange',
    'sandybrown',
    'lightsalmon',
    'wheat',
    'gold',
    'yellow',
    'peru',
    'red',
    'crimson',
    'magenta',
    'blue',
    'mediumblue',
    'darkblue',]


    # Napataan välimuuttujaan
df_c = df

    # Kärryt per tunti
df_c['timebyhour'].value_counts(sort=False, normalize=True).mul(100).plot(kind='bar', color=my_colors, edgecolor='black');


# X-akselin teksti
plt.xlabel("Kellonaika", labelpad=14)


    # Pystyakselin teksti
plt.ylabel("Osuus kokonaisuudesta (%)", labelpad=14)
    
    
    # Otsikko johon päivämäärät datasta
plt.title("Kärryjä kaupassa kellonaikaan aikajaksolla:\n " + str(df.timestamp.dt.date.iloc[0]) + " - " + str(df.timestamp.dt.date.iloc[-1]), y=1.02, fontsize=10);

# %%
df['day'] = df.timestamp.dt.day
df['week'] = df.timestamp.dt.week
df['month'] = df.timestamp.dt.month

# %%
df.head(15)
# Out:
#     node_id               timestamp     x    y  timebyhour  day  week  month
# 0         1 2020-06-24 15:20:08.533  2762 -257          15   24    26      6
# 1         1 2020-06-24 15:20:08.620  2870 -344          15   24    26      6
# 2         1 2020-06-24 15:20:09.623  2916 -344          15   24    26      6
# 3         1 2020-06-24 15:20:09.623  2894 -254          15   24    26      6
# 4         1 2020-06-24 15:20:10.116  2888 -188          15   24    26      6
# 5         1 2020-06-24 15:20:11.086  2910 -200          15   24    26      6
# 6         1 2020-06-24 15:20:11.820  2924 -111          15   24    26      6
# 7         1 2020-06-24 15:20:12.995  2928    5          15   24    26      6
# 8         1 2020-06-24 15:20:13.596  2987    6          15   24    26      6
# 9         1 2020-06-24 15:20:14.482  3038   -8          15   24    26      6
# 10        1 2020-06-24 15:20:15.659  3173 -101          15   24    26      6
# 11        1 2020-06-24 15:20:15.837  3187 -108          15   24    26      6
# 12        1 2020-06-24 15:20:17.590  3349  -92          15   24    26      6
# 13        1 2020-06-24 15:20:21.982  3642  252          15   24    26      6
# 14        1 2020-06-24 15:20:22.715  3553  251          15   24    26      6

# %%
df.dtypes
# Out:
# node_id                int64
# timestamp     datetime64[ns]
# x                      int64
# y                      int64
# timebyhour             int64
# day                    int64
# week                   int64
# month                  int64
# dtype: object

# %%
df_new = df
df_new = df_new.drop(df_new[(df_new.timestamp.dt.month > 8)].index)
df_new = df_new.drop(df_new[(df_new.timestamp.dt.month < 8)].index)
df_new = df_new.drop(df_new[(df_new.timestamp.dt.day < 12 )].index)
df_new = df_new.drop(df_new[(df_new.timestamp.dt.day > 20)].index)
df_new
# Out:
#          node_id               timestamp     x     y  timebyhour  day  week  \
# 166309         1 2020-08-12 08:00:04.602  2772  -358           8   12    33
# 166310         1 2020-08-12 08:00:14.601  2772  -355           8   12    33
# 166311         1 2020-08-12 08:00:23.603  2772  -352           8   12    33
# 166312         1 2020-08-12 08:00:32.603  2775  -356           8   12    33
# 166313         1 2020-08-12 08:00:53.601  2773  -356           8   12    33
# ...          ...                     ...   ...   ...         ...  ...   ...
# 4752994       13 2020-08-20 21:59:11.821  1454  1305          21   20    34
# 4752995       13 2020-08-20 21:59:21.821  1397  1275          21   20    34
# 4752996       13 2020-08-20 21:59:31.821  1417  1277          21   20    34
# 4752997       13 2020-08-20 21:59:41.821  1412  1280          21   20    34
# 4752998       13 2020-08-20 21:59:51.821  1459  1278          21   20    34
#
#          month
# 166309       8
# 166310       8
# 166311       8
# 166312       8
# 166313       8
# ...        ...
# 4752994      8
# 4752995      8
# 4752996      8
# 4752997      8
# 4752998      8
#
# [341528 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd


    # Määritetään värit graafia varten
'''
    my_colors = [
    'darkorange',
    'orange',
    'sandybrown',
    'lightsalmon',
    'wheat',
    'gold',
    'yellow',
    'peru',
    'red',
    'crimson',
    'magenta',
    'blue',
    'mediumblue',
    'darkblue',]
'''

    # Napataan välimuuttujaan
df_d = df_new

    # Kärryt per tunti
df_d['timebyhour'].value_counts(sort=False, normalize=True).mul(100).plot(kind='bar',  edgecolor='black'); #color=my_colors,


# X-akselin teksti
plt.xlabel("Kellonaika", labelpad=14)


    # Pystyakselin teksti
plt.ylabel("Osuus kokonaisuudesta (%)", labelpad=14)
    
    
    # Otsikko johon päivämäärät datasta
plt.title("Kärryjä kaupassa kellonaikaan aikajaksolla:\n " + str(df_new.timestamp.dt.date.iloc[0]) + " - " + str(df_new.timestamp.dt.date.iloc[-1]), y=1.02, fontsize=10);

# %%
def aukioloajat(df):
    
    df = df.drop(df[(df.timestamp.dt.hour < 8)].index)
    df = df.drop(df[(df.timestamp.dt.hour > 21)].index)
    df['day'] = df.timestamp.dt.day
    df['week'] = df.timestamp.dt.week
    df['month'] = df.timestamp.dt.month
    df['dayofweek'] = df.timestamp.dt.dayofweek
    
    
    
    if df.timestamp.dt.daysofweek = 6:
        
        df = df.drop(df[(df.timestamp.dt.hour < 10) & df.timestamp.dt.hour > 21)].index)

# %%
df_new = df

# %%
df_new['dayofweek'] = df_new.timestamp.dt.dayofweek

# %%
df_new
# Out:
#          node_id               timestamp     x     y  timebyhour  day  week  \
# 0              1 2020-06-24 15:20:08.533  2762  -257          15   24    26
# 1              1 2020-06-24 15:20:08.620  2870  -344          15   24    26
# 2              1 2020-06-24 15:20:09.623  2916  -344          15   24    26
# 3              1 2020-06-24 15:20:09.623  2894  -254          15   24    26
# 4              1 2020-06-24 15:20:10.116  2888  -188          15   24    26
# ...          ...                     ...   ...   ...         ...  ...   ...
# 4999995       13 2020-09-21 17:06:33.956  1563  1188          17   21    39
# 4999996       13 2020-09-21 17:06:43.956  1545  1193          17   21    39
# 4999997       13 2020-09-21 17:06:53.956  1550  1195          17   21    39
# 4999998       13 2020-09-21 17:07:03.956  1550  1194          17   21    39
# 4999999       13 2020-09-21 17:07:13.956  1567  1188          17   21    39
#
#          month  dayofweek
# 0            6          2
# 1            6          2
# 2            6          2
# 3            6          2
# 4            6          2
# ...        ...        ...
# 4999995      9          0
# 4999996      9          0
# 4999997      9          0
# 4999998      9          0
# 4999999      9          0
#
# [4435482 rows x 9 columns]

# %%
# Kaikkien 6-päivien indeksit listaan
df_temp = df_new[df_new.timestamp.dt.dayofweek == 6].index.values.tolist()
df_temp
# Out:
# [7997,
#  7998,
#  7999,
#  8000,
#  8001,
#  8002,
#  8003,
#  8004,
#  8005,
#  8006,
#  8007,
#  8008,
#  8009,
#  8010,
#  8011,
#  8012,
#  8013,
#  8014,
#  8015,
#  8016,
#  8017,
#  8018,
#  8019,
#  8020,
#  8021,
#  8022,
#  8023,
#  8024,
#  8025,
#  8026,
#  8027,
#  8028,
#  8029,
#  8030,
#  8031,
#  8032,
#  8033,
#  8034,
#  8035,
#  8036,
#  8037,
#  8038,
#  8039,
#  8040,
#  8041,
#  8042,
#  8043,
#  8044,
#  8045,
#  8046,
#  8047,
#  8048,
#  8049,
#  8050,
#  8051,
#  8052,
#  8053,
#  8054,
#  8055,
#  8056,
#  8057,
#  8058,
#  8059,
#  8060,
#  8061,
#  8062,
#  8063,
#  8066,
#  8067,
#  8068,
#  8069,
#  8070,
#  8071,
#  8072,
#  8073,
#  8074,
#  8076,
#  8077,
#  8078,
#  8079,
#  8080,
#  8081,
#  8085,
#  8086,
#  8087,
#  8088,
#  8094,
#  8095,
#  8096,
#  8097,
#  8098,
#  8099,
#  8100,
#  8101,
#  8102,
#  8103,
#  8104,
#  8105,
#  8106,
#  8107,
#  8108,
#  8109,
#  8110,
#  8111,
#  8112,
#  8113,
#  8114,
#  8115,
#  8116,
#  8117,
#  8118,
#  8119,
#  8120,
#  8121,
#  8122,
#  8123,
#  8124,
#  8125,
#  8126,
#  8127,
#  8128,
#  8129,
#  8130,
#  8131,
#  8132,
#  8133,
#  8134,
#  8135,
#  8136,
#  8137,
#  8138,
#  8139,
#  8140,
#  8141,
#  8142,
#  8143,
#  8144,
#  8145,
#  8146,
#  8147,
#  8148,
#  8149,
#  8150,
#  8151,
#  8152,
#  8153,
#  8154,
#  8155,
#  8156,
#  8157,
#  8158,
#  8159,
#  8160,
#  8161,
#  8162,
#  8163,
#  8164,
#  8165,
#  8166,
#  8167,
#  8168,
#  8169,
#  8170,
#  8171,
#  8172,
#  8173,
#  8174,
#  8175,
#  8176,
#  8177,
#  8178,
#  8179,
#  8180,
#  8181,
#  8182,
#  8183,
#  8184,
#  8185,
#  8186,
#  8187,
#  8188,
#  8189,
#  8190,
#  8191,
#  8192,
#  8193,
#  8194,
#  8195,
#  8196,
#  8197,
#  8198,
#  8199,
#  8200,
#  8201,
#  8202,
#  8203,
#  8204,
#  8205,
#  8206,
#  8207,
#  8208,
#  8209,
#  8210,
#  8211,
#  8212,
#  8213,
#  8214,
#  8215,
#  8216,
#  8217,
#  8218,
#  8219,
#  8220,
#  8221,
#  8222,
#  8223,
#  8224,
#  8225,
#  8226,
#  8227,
#  8228,
#  8229,
#  8230,
#  8231,
#  8232,
#  8233,
#  8234,
#  8235,
#  8236,
#  8237,
#  8238,
#  8239,
#  8240,
#  8241,
#  8242,
#  8243,
#  8244,
#  8245,
#  8246,
#  8247,
#  8248,
#  8249,
#  8250,
#  8251,
#  8252,
#  8253,
#  8254,
#  8255,
#  8256,
#  8257,
#  8258,
#  8259,
#  8260,
#  8261,
#  8262,
#  8263,
#  8264,
#  8265,
#  8266,
#  8267,
#  8268,
#  8269,
#  8270,
#  8271,
#  8272,
#  8273,
#  8274,
#  8275,
#  8276,
#  8277,
#  8278,
#  8279,
#  8280,
#  8281,
#  8282,
#  8283,
#  8284,
#  8285,
#  8286,
#  8287,
#  8288,
#  8289,
#  8290,
#  8291,
#  8292,
#  8293,
#  8294,
#  8295,
#  8296,
#  8297,
#  8298,
#  8299,
#  8300,
#  8301,
#  8302,
#  8303,
#  8304,
#  8305,
#  8306,
#  8307,
#  8308,
#  8309,
#  8310,
#  8311,
#  8312,
#  8313,
#  8314,
#  8315,
#  8316,
#  8317,
#  8318,
#  8319,
#  8320,
#  8321,
#  8322,
#  8323,
#  8324,
#  8325,
#  8326,
#  8327,
#  8328,
#  8329,
#  8330,
#  8331,
#  8332,
#  8333,
#  8334,
#  8335,
#  8336,
#  8337,
#  8338,
#  8339,
#  8340,
#  8341,
#  8342,
#  8343,
#  8344,
#  8345,
#  8346,
#  8347,
#  8348,
#  8349,
#  8350,
#  8351,
#  8352,
#  8353,
#  8354,
#  8355,
#  8356,
#  8357,
#  8358,
#  8359,
#  8360,
#  8361,
#  8362,
#  8363,
#  8364,
#  8365,
#  8366,
#  8367,
#  8368,
#  8369,
#  8370,
#  8371,
#  8372,
#  8373,
#  8374,
#  8375,
#  8376,
#  8377,
#  8378,
#  8379,
#  8380,
#  8381,
#  8382,
#  8383,
#  8384,
#  8385,
#  8386,
#  8387,
#  8388,
#  8389,
#  8390,
#  8391,
#  8392,
#  8393,
#  8394,
#  8395,
#  8396,
#  8397,
#  8398,
#  8399,
#  8400,
#  8401,
#  8402,
#  8403,
#  8404,
#  8405,
#  8406,
#  8407,
#  8408,
#  8409,
#  8410,
#  8411,
#  8412,
#  8413,
#  8414,
#  8415,
#  8416,
#  8417,
#  8418,
#  8419,
#  8420,
#  8421,
#  8422,
#  8423,
#  8424,
#  8425,
#  8426,
#  8427,
#  8428,
#  8429,
#  8430,
#  8431,
#  8432,
#  8433,
#  8434,
#  8435,
#  8436,
#  8437,
#  8438,
#  8439,
#  8440,
#  8441,
#  8442,
#  8443,
#  8444,
#  8445,
#  8446,
#  8447,
#  8448,
#  8449,
#  8450,
#  8451,
#  8452,
#  8453,
#  8454,
#  8455,
#  8456,
#  8457,
#  8458,
#  8459,
#  8460,
#  8461,
#  8462,
#  8463,
#  8464,
#  8465,
#  8466,
#  8467,
#  8468,
#  8469,
#  8470,
#  8471,
#  8472,
#  8473,
#  8474,
#  8475,
#  8476,
#  8477,
#  8478,
#  8479,
#  8480,
#  8481,
#  8482,
#  8483,
#  8484,
#  8485,
#  8486,
#  8487,
#  8488,
#  8489,
#  8490,
#  8491,
#  8492,
#  8493,
#  8494,
#  8495,
#  8496,
#  8497,
#  8498,
#  8499,
#  8500,
#  8501,
#  8502,
#  8503,
#  8504,
#  8505,
#  8506,
#  8507,
#  8508,
#  8509,
#  8510,
#  8511,
#  8512,
#  8513,
#  8514,
#  8515,
#  8516,
#  8517,
#  8518,
#  8519,
#  8520,
#  8521,
#  8522,
#  8523,
#  8524,
#  8525,
#  8526,
#  8527,
#  8528,
#  8529,
#  8530,
#  8531,
#  8532,
#  8533,
#  8534,
#  8535,
#  8536,
#  8537,
#  8538,
#  8539,
#  8540,
#  8541,
#  8542,
#  8543,
#  8544,
#  8545,
#  8546,
#  8547,
#  8548,
#  8549,
#  8550,
#  8551,
#  8552,
#  8553,
#  8554,
#  8555,
#  8556,
#  8557,
#  8558,
#  8559,
#  8560,
#  8561,
#  8562,
#  8563,
#  8564,
#  8565,
#  8566,
#  8567,
#  8568,
#  8569,
#  8570,
#  8571,
#  8572,
#  8573,
#  8574,
#  8575,
#  8576,
#  8577,
#  8578,
#  8579,
#  8580,
#  8581,
#  8582,
#  8583,
#  8584,
#  8585,
#  8586,
#  8587,
#  8588,
#  8589,
#  8590,
#  8591,
#  8592,
#  8593,
#  8594,
#  8595,
#  8596,
#  8597,
#  8598,
#  8599,
#  8600,
#  8601,
#  8602,
#  8603,
#  8604,
#  8605,
#  8606,
#  8607,
#  8608,
#  8609,
#  8610,
#  8611,
#  8612,
#  8613,
#  8614,
#  8615,
#  8616,
#  8617,
#  8618,
#  8619,
#  8620,
#  8621,
#  8622,
#  8623,
#  8624,
#  8625,
#  8626,
#  8627,
#  8628,
#  8629,
#  8630,
#  8631,
#  8632,
#  8633,
#  8634,
#  8635,
#  8636,
#  8637,
#  8638,
#  8639,
#  8640,
#  8641,
#  8642,
#  8643,
#  8644,
#  8645,
#  8646,
#  8647,
#  8648,
#  8649,
#  8650,
#  8651,
#  8652,
#  8653,
#  8654,
#  8655,
#  8656,
#  8657,
#  8658,
#  8659,
#  8660,
#  8661,
#  8662,
#  8663,
#  8664,
#  8665,
#  8666,
#  8667,
#  8668,
#  8669,
#  8670,
#  8671,
#  8672,
#  8673,
#  8674,
#  8675,
#  8676,
#  8677,
#  8678,
#  8679,
#  8680,
#  8681,
#  8682,
#  8683,
#  8684,
#  8685,
#  8686,
#  8687,
#  8688,
#  8689,
#  8690,
#  8691,
#  8692,
#  8693,
#  8694,
#  8695,
#  8696,
#  8697,
#  8698,
#  8699,
#  8700,
#  8701,
#  8702,
#  8703,
#  8704,
#  8705,
#  8706,
#  8707,
#  8708,
#  8709,
#  8710,
#  8711,
#  8712,
#  8715,
#  8716,
#  8717,
#  8718,
#  8721,
#  8722,
#  8723,
#  8724,
#  8725,
#  8726,
#  8727,
#  8728,
#  8729,
#  8730,
#  8731,
#  8732,
#  8733,
#  8734,
#  8735,
#  8736,
#  8737,
#  8738,
#  8742,
#  8744,
#  8745,
#  8746,
#  8747,
#  8748,
#  8749,
#  8750,
#  8751,
#  8752,
#  8753,
#  8754,
#  8755,
#  8756,
#  8757,
#  8758,
#  8759,
#  8760,
#  8761,
#  8762,
#  8763,
#  8764,
#  8765,
#  8766,
#  8767,
#  8768,
#  8769,
#  8770,
#  8771,
#  8772,
#  8773,
#  8774,
#  8775,
#  8776,
#  8777,
#  8778,
#  8779,
#  8780,
#  8781,
#  8782,
#  8783,
#  8784,
#  8785,
#  8786,
#  8787,
#  8788,
#  8789,
#  8790,
#  8791,
#  8792,
#  8793,
#  8794,
#  8795,
#  8796,
#  8797,
#  8798,
#  8799,
#  8800,
#  8801,
#  8802,
#  8803,
#  8804,
#  8805,
#  8806,
#  8807,
#  8808,
#  8809,
#  8810,
#  8811,
#  8812,
#  8813,
#  8814,
#  8815,
#  8816,
#  8817,
#  8818,
#  8819,
#  8820,
#  8821,
#  8822,
#  8823,
#  8824,
#  8825,
#  8826,
#  8827,
#  8828,
#  8829,
#  8830,
#  8831,
#  8832,
#  8833,
#  8834,
#  8835,
#  8836,
#  8837,
#  8838,
#  8839,
#  8840,
#  8841,
#  8842,
#  8843,
#  8844,
#  8845,
#  8846,
#  8847,
#  8848,
#  8849,
#  8850,
#  8851,
#  8852,
#  8853,
#  8854,
#  8855,
#  8856,
#  8857,
#  8858,
#  8859,
#  8860,
#  8861,
#  8862,
#  8863,
#  8864,
#  8865,
#  8866,
#  8867,
#  8868,
#  8869,
#  8870,
#  8871,
#  8872,
#  8873,
#  8874,
#  8875,
#  8876,
#  8877,
#  8878,
#  8879,
#  8880,
#  8881,
#  8882,
#  8883,
#  8884,
#  8885,
#  8886,
#  8887,
#  8888,
#  8889,
#  8890,
#  8891,
#  8892,
#  8893,
#  8894,
#  8895,
#  8896,
#  8897,
#  8898,
#  8899,
#  8900,
#  8901,
#  8902,
#  8903,
#  8904,
#  8905,
#  8906,
#  8907,
#  8908,
#  8909,
#  8910,
#  8911,
#  8912,
#  8913,
#  8914,
#  8915,
#  8916,
#  8917,
#  8918,
#  8919,
#  8920,
#  8921,
#  8922,
#  8923,
#  8924,
#  8925,
#  8926,
#  8927,
#  8928,
#  8929,
#  8930,
#  8931,
#  8932,
#  8933,
#  8934,
#  8935,
#  8936,
#  8937,
#  8938,
#  8939,
#  8940,
#  8941,
#  8942,
#  8943,
#  8944,
#  8945,
#  8946,
#  8947,
#  8948,
#  8949,
#  8950,
#  8951,
#  8952,
#  8953,
#  8954,
#  8955,
#  8956,
#  8957,
#  8958,
#  8959,
#  8960,
#  8961,
#  8962,
#  8963,
#  8964,
#  8965,
#  8966,
#  8967,
#  8968,
#  8969,
#  8970,
#  8971,
#  8972,
#  8973,
#  8974,
#  8975,
#  8976,
#  8977,
#  8978,
#  8979,
#  8980,
#  8981,
#  8982,
#  8983,
#  8984,
#  8985,
#  8986,
#  8987,
#  8988,
#  8989,
#  8990,
#  8991,
#  8992,
#  8993,
#  8994,
#  8995,
#  8996,
#  8997,
#  8998,
#  8999,
#  9000,
#  9001,
#  9002,
#  9003,
#  9004,
#  9005,
#  9006,
#  9007,
#  9008,
#  9009,
#  9010,
#  9011,
#  9012,
#  9013,
#  9014,
#  9015,
#  ...]

# %%
# Suodatetaan kaikkien 6 päivän indekseistä alle 10 tuntiset
df_new_temp = df_new.iloc[df_temp][df_new.iloc[df_temp].timestamp.dt.hour > 10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    2109         try:
# -> 2110             return self.obj._take_with_is_copy(key, axis=axis)
#    2111         except IndexError:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3394         new_data = self._data.take(
# -> 3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1385         if convert:
# -> 1386             indexer = maybe_convert_indices(indexer, n)
#    1387
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexers.py in maybe_convert_indices(indices, n)
#     211     if mask.any():
# --> 212         raise IndexError("indices are out-of-bounds")
#     213     return indices
#
# IndexError: indices are out-of-bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-08a7ef412ab9> in <module>
#       1 # Suodatetaan kaikkien 6 päivän indekseistä alle 10 tuntiset
# ----> 2 df_new_temp = df_new.iloc[df_temp][df_new.iloc[df_temp].timestamp.dt.hour > 10]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2126         # a list of integers
#    2127         elif is_list_like_indexer(key):
# -> 2128             return self._get_list_axis(key, axis=axis)
#    2129
#    2130         # a single integer
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    2111         except IndexError:
#    2112             # re-raise with different error message
# -> 2113             raise IndexError("positional indexers are out-of-bounds")
#    2114
#    2115     def _getitem_axis(self, key, axis: int):
#
# IndexError: positional indexers are out-of-bounds

# %%
# Poistetaan alkuperäisestä dataframesta kyseiset arvot
df_new = df_new.drop(df_new.index[df_new_temp.index.values])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    2109         try:
# -> 2110             return self.obj._take_with_is_copy(key, axis=axis)
#    2111         except IndexError:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3394         new_data = self._data.take(
# -> 3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1385         if convert:
# -> 1386             indexer = maybe_convert_indices(indexer, n)
#    1387
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexers.py in maybe_convert_indices(indices, n)
#     211     if mask.any():
# --> 212         raise IndexError("indices are out-of-bounds")
#     213     return indices
#
# IndexError: indices are out-of-bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-346749c5c42f> in <module>
#       3
#       4 # Suodatetaan kaikkien 6 päivän indekseistä alle 10 tuntiset
# ----> 5 df_new_temp = df_new.iloc[df_temp][df_new.iloc[df_temp].timestamp.dt.hour.values > 10]
#       6
#       7 # Poistetaan alkuperäisestä dataframesta kyseiset arvot
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2126         # a list of integers
#    2127         elif is_list_like_indexer(key):
# -> 2128             return self._get_list_axis(key, axis=axis)
#    2129
#    2130         # a single integer
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    2111         except IndexError:
#    2112             # re-raise with different error message
# -> 2113             raise IndexError("positional indexers are out-of-bounds")
#    2114
#    2115     def _getitem_axis(self, key, axis: int):
#
# IndexError: positional indexers are out-of-bounds

# %%
print(pd.__version__)
# Out:
# 1.0.1
